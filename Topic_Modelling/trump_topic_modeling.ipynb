# %% [markdown]
# # 1. Dataset Check

# %%
# Libraries
import pandas as pd
from google.colab import drive
import datetime

# %%
# Connect to Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# read dataset
data = pd.read_csv('/content/drive/MyDrive/MasterThesis/Reddit_Data/cleaned_trump.csv')
data.head()
# Out:
#                     thread_title      thread_time_utc  thread_score  \
# 0  crypto meme coin trading 2025  2025-01-17 11:06:53             0
# 1  crypto meme coin trading 2025  2025-01-17 11:06:53             0
# 2  crypto meme coin trading 2025  2025-01-17 11:06:53             0
# 3  crypto meme coin trading 2025  2025-01-17 11:06:53             0
# 4  crypto meme coin trading 2025  2025-01-17 11:06:53             0
#
#       comment_time_utc  comment_score  \
# 0  2025-01-18 05:13:47              1
# 1  2025-01-17 18:16:41              1
# 2  2025-01-17 15:22:42              1
# 3  2025-01-17 14:42:22              1
# 4  2025-01-17 11:06:54              1
#
#                                         comment_text subreddit  \
# 0  i mean i have a group that has 1520 ppl in it ...   therace
# 1  wow what an inspiring journey its super cool t...   therace
# 2                                                 ya   therace
# 3  ok fine drop the trading group about to be a c...   therace
# 4  copy real trades on the free afterhour app fro...   therace
#
#                                            full_text
# 0  crypto meme coin trading 2025 i mean i have a ...
# 1  crypto meme coin trading 2025 wow what an insp...
# 2                   crypto meme coin trading 2025 ya
# 3  crypto meme coin trading 2025 ok fine drop the...
# 4  crypto meme coin trading 2025 copy real trades...

# %%
data.shape
# Out:
# (64181, 8)

# %%
# Droping the data aqfter 28.02.2025 to align with the blockchain dat aanalysis
data['comment_time_utc'] = pd.to_datetime(data['comment_time_utc'])
cutoff = pd.to_datetime('2025-02-28')   # no utc=True
data.drop(data[data['comment_time_utc'] > cutoff].index, inplace=True)

# %%
data.shape
# Out:
# (56775, 8)

# %%
data.nunique()
# Out:
# thread_title          354
# thread_time_utc       371
# thread_score          174
# comment_time_utc    54018
# comment_score         500
# comment_text        51890
# subreddit              11
# full_text           53782
# dtype: int64

# %%
# dropping duplicates in order to avoid using bots comments or removed comments from analysis
duplicates = data[data.duplicated(subset='comment_text', keep=False)]
duplicates
# Out:
#                                             thread_title      thread_time_utc  \
# 2                          crypto meme coin trading 2025  2025-01-17 11:06:53
# 4                          crypto meme coin trading 2025  2025-01-17 11:06:53
# 50     trump plans to designate crypto as a national ...  2025-01-17 13:59:58
# 60     trump plans to designate crypto as a national ...  2025-01-17 13:59:58
# 69     trump plans to designate crypto as a national ...  2025-01-17 13:59:58
# ...                                                  ...                  ...
# 57046  why would trump or any american president be p...  2025-02-27 20:08:46
# 57064  why would trump or any american president be p...  2025-02-27 20:08:46
# 57133  why would trump or any american president be p...  2025-02-27 20:08:46
# 57170  why would trump or any american president be p...  2025-02-27 20:08:46
# 57180  why would trump or any american president be p...  2025-02-27 20:08:46
#
#        thread_score    comment_time_utc  comment_score  \
# 2                 0 2025-01-17 15:22:42              1
# 4                 0 2025-01-17 11:06:54              1
# 50              594 2025-01-17 17:13:29             30
# 60              594 2025-01-17 14:36:44              0
# 69              594 2025-01-17 14:36:42              1
# ...             ...                 ...            ...
# 57046            51 2025-02-27 21:55:01              0
# 57064            51 2025-02-27 21:12:20              2
# 57133            51 2025-02-27 20:37:39              0
# 57170            51 2025-02-27 21:03:54              4
# 57180            51 2025-02-27 20:49:30              1
#
#                                             comment_text       subreddit  \
# 2                                                     ya         therace
# 4      copy real trades on the free afterhour app fro...         therace
# 50                                               deleted  CryptoCurrency
# 60     greetings elarkspur your comment contained a l...  CryptoCurrency
# 69                                               removed  CryptoCurrency
# ...                                                  ...             ...
# 57046                                            deleted   CryptoMarkets
# 57064                                            removed   CryptoMarkets
# 57133                                         corruption   CryptoMarkets
# 57170                                            removed   CryptoMarkets
# 57180                                             got em   CryptoMarkets
#
#                                                full_text
# 2                       crypto meme coin trading 2025 ya
# 4      crypto meme coin trading 2025 copy real trades...
# 50     trump plans to designate crypto as a national ...
# 60     trump plans to designate crypto as a national ...
# 69     trump plans to designate crypto as a national ...
# ...                                                  ...
# 57046  why would trump or any american president be p...
# 57064  why would trump or any american president be p...
# 57133  why would trump or any american president be p...
# 57170  why would trump or any american president be p...
# 57180  why would trump or any american president be p...
#
# [6346 rows x 8 columns]

# %%
data = data.drop_duplicates(subset='comment_text', keep='first')

# %%
data.shape
# Out:
# (51891, 8)

# %%
data = data[data["comment_text"].str.split().str.len() > 4]

# %%
data.shape
# Out:
# (45654, 8)

# %% [markdown]
# # 2. Topic Modelling

# %%
# !pip install bertopic[visualization] umap-learn hdbscan
# Out:
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.11/dist-packages (0.5.7)
# Requirement already satisfied: hdbscan in /usr/local/lib/python3.11/dist-packages (0.8.40)
# Requirement already satisfied: bertopic[visualization] in /usr/local/lib/python3.11/dist-packages (0.17.0)
# WARNING: bertopic 0.17.0 does not provide the extra 'visualization'
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from bertopic[visualization]) (2.0.2)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.11/dist-packages (from bertopic[visualization]) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.11/dist-packages (from bertopic[visualization]) (5.24.1)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.11/dist-packages (from bertopic[visualization]) (1.6.1)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from bertopic[visualization]) (4.1.0)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.11/dist-packages (from bertopic[visualization]) (4.67.1)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (1.15.3)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (0.5.13)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from hdbscan) (1.5.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic[visualization]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic[visualization]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic[visualization]) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=4.7.0->bertopic[visualization]) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=4.7.0->bertopic[visualization]) (24.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0->bertopic[visualization]) (3.6.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (4.51.3)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (2.6.0+cu124)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (0.31.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (11.2.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (4.13.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2025.3.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic[visualization]) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.32.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic[visualization]) (1.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic[visualization]) (1.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic[visualization]) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic[visualization]) (0.5.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2025.4.26)

# %%
# Import libraries
import pandas as pd
import umap
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer
from hdbscan import HDBSCAN
import nltk
import re
from nltk.corpus import stopwords
import spacy

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
nlp = spacy.load("en_core_web_sm")

# Text cleaning + lemmatization function
def clean_text(text):
    text = str(text).lower()
    text = re.sub(r"http\S+|www.\S+", "", text)
    text = re.sub(r"[^a-zA-Z0-9\s$]", "", text)
    text = re.sub(r"\s+", " ", text).strip()

    # Lemmatize and remove stopwords
    doc = nlp(text)
    words = [token.lemma_ for token in doc if token.lemma_ not in stop_words and not token.is_punct and not token.is_space]

    cleaned_text = " ".join(words)
    return cleaned_text
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Load cleaned dataset from previous part
df = data

# Cleaning using the prepared function
df["clean_comment_text"] = df["comment_text"].dropna().apply(clean_text)
texts = df["clean_comment_text"].dropna().tolist()

# HDBSCAN
hdbscan_model = HDBSCAN(
    min_cluster_size=25,
    min_samples=1,
    prediction_data=True
)

# UMAP model
umap_model = umap.UMAP(
    n_neighbors=20,
    n_components=5,
    min_dist=0.0,
    metric='cosine',
    random_state=42
)

# Embedding model
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

# Create BERTopic model
topic_model = BERTopic(
    hdbscan_model=hdbscan_model,
    umap_model=umap_model,
    embedding_model=embedding_model,
    calculate_probabilities=True,
    language="english",
    verbose=True
)

topics, probs = topic_model.fit_transform(texts)
# Out:
# 2025-05-14 14:01:30,860 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/1427 [00:00<?, ?it/s]
# 2025-05-14 14:01:48,746 - BERTopic - Embedding - Completed ✓
# 2025-05-14 14:01:48,750 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-05-14 14:02:58,069 - BERTopic - Dimensionality - Completed ✓
# 2025-05-14 14:02:58,073 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-05-14 14:08:35,763 - BERTopic - Cluster - Completed ✓
# 2025-05-14 14:08:35,778 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-05-14 14:08:36,561 - BERTopic - Representation - Completed ✓

# %%
# After checking different options, we needed to reduce the number of topics. Based on the topic visualiations numer 8 seemed the most optimal
topic_model.reduce_topics(texts, nr_topics=10)
# Out:
# 2025-05-14 14:08:37,978 - BERTopic - Topic reduction - Reducing number of topics
# 2025-05-14 14:08:38,048 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-05-14 14:08:38,525 - BERTopic - Representation - Completed ✓
# 2025-05-14 14:08:38,531 - BERTopic - Topic reduction - Reduced number of topics from 349 to 10

# %% [markdown]
# # 3. Visualization and model evaluation

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="96525fb2-6f32-472d-b59d-0ae24effc65e" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96525fb2-6f32-472d-b59d-0ae24effc65e")) {                    Plotly.newPlot(                        "96525fb2-6f32-472d-b59d-0ae24effc65e",                        [{"customdata":[[0,"trump | coin | buy | crypto | money",19297],[1,"go | bag | get | think | people",4255],[2,"vote | people | biden | trump | would",2750],[3,"whale | kraken | boat | miss | pole",148],[4,"comment | link | moderator | please | telegram",133],[5,"toshi | xcn | sokka | haiku | blast",36],[6,"art | artist | painting | value | copyright",29],[7,"adoption | mass | mainstream | suuuure | permissionless",26],[8,"quantum | computer | computing | hack | crypto",26]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[19297,4255,2750,148,133,36,29,26,26],"sizemode":"area","sizeref":12.060625,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[8.748351,8.92718,7.8937087,8.658172,8.173693,9.27703,7.156133,6.741782,7.7783194],"xaxis":"x","y":[7.39221,6.6452847,6.1660275,7.953455,7.177581,6.4098034,6.9397025,5.671113,7.7831597],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.333333333333333 ...

# %%
# Visualize hierarchy of topics
topic_model.visualize_hierarchy()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7c993c28-5919-449f-a29f-65551cd93280" class="plotly-graph-div" style="height:335px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c993c28-5919-449f-a29f-65551cd93280")) {                    Plotly.newPlot(                        "7c993c28-5919-449f-a29f-65551cd93280",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.30833146969057057,0.30833146969057057,0.0],"xaxis":"x","y":[-15.0,-15.0,-25.0,-25.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.30833146969057057,0.3455591058831524,0.3455591058831524,0.0],"xaxis":"x","y":[-20.0,-20.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.8860182803179186,0.8860182803179186,0.3455591058831524],"xaxis":"x","y":[-5.0,-5.0,-27.5,-27.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.9595641467123651,0.9595641467123651,0.0],"xaxis":"x","y":[-55.0,-55.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.9595641467123651,0.9736839964439928,0.9736839964439928,0.0],"xaxis":"x","y":[-60.0,-60.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.9894421931082064,0.9894421931082064,0.9736839964439928],"xaxis":"x","y":[-45.0,-45.0,-67.5,-67.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.9894421931082064,0.9965428341193084,0.9965428341193084,0.0],"xaxis":"x","y":[-56.25,-56.25,-85.0,-85.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.8860182803179186,1.1376226898552908,1.1376226898552908,0.9965428341193084],"xaxis":"x","y":[-16.25,-16.25,-70.625,-70.625],"yaxis":"y","type":"scatter"}],                        {"autosize":false,"height":335,"hovermode":"closest","showlegend":false,"width":1000,"xaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"ticks":"outside","type":"linear","zeroline":false},"yaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"tickmode":"array","ticks":"outside","ticktext":["3_whale_kraken_boat","1_go_bag_get","0_trump_coin_buy","2_vote_people_biden","5_toshi_xcn_sokka","6_art_artist_painting","7_adoption_mass_mainstream","8_quantum_computer_computing","4_comment_link_moderator"],"tickvals":[-5.0,-15.0,-25.0,-35.0,-45.0,-55.0,-65.0,-75.0,-85.0],"type":"linear","zeroline":false,"range":[-90.0,0.0]},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3 ...

# %%
# Visualize the top topics
topic_model.visualize_barchart(top_n_topics=10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0c411643-46e3-4f57-bbb1-366b25952e37" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c411643-46e3-4f57-bbb1-366b25952e37")) {                    Plotly.newPlot(                        "0c411643-46e3-4f57-bbb1-366b25952e37",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.026630427223293084,0.02760470449614922,0.029628958606596673,0.03635516796050018,0.03699046638722938],"y":["money  ","crypto  ","buy  ","coin  ","trump  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.027775814858050783,0.027775946981196935,0.029054069848804716,0.03601295886648887,0.04282762143699934],"y":["people  ","think  ","get  ","bag  ","go  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.022963444322876017,0.022971925702029477,0.02437613955821614,0.029907230399639773,0.04082352636015224],"y":["would  ","trump  ","biden  ","people  ","vote  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.05641954919686525,0.07058817763546683,0.14938277161376134,0.24481815776517943,0.26548173457027946],"y":["pole  ","miss  ","boat  ","kraken  ","whale  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.22226257535461627,0.2438757634050565,0.26725949054643655,0.2759903647478629,0.30120628208128936],"y":["telegram  ","please  ","moderator  ","link  ","comment  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.06724830081646571,0.08065819751194617,0.08065819751194617,0.16521002253248737,1.0701281301335346],"y":["blast  ","haiku  ","sokka  ","xcn  ","toshi  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.06457872652803737,0.09503969925659048,0.14328945275023078,0.21497987632343243,0.30550557885808355],"y":["copyright  ","value  ","painting  ","artist  ","art  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.06492503601229802,0.07250175057253587,0.07709629969236809,0.21139268955896987,0.6098429983903307],"y":["permissionless  ","suuuure  ","mainstream  ","mass  ","adoption  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.07018110591843782,0.08689528085163611,0.18987755524649141,0.19810795939956954,0.5941794451297217],"y":["crypto  ","hack  ","computing  ","computer  ","quantum  "],"type":"bar","xaxis":"x9","yaxis":"y9"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"# ...

# %%
trump_topic = topic_model.get_topic_info()
trump_topic
# Out:
#    Topic  Count                                Name  \
# 0     -1  18954         -1_coin_trump_crypto_people
# 1      0  19297             0_trump_coin_buy_crypto
# 2      1   4255                  1_go_bag_get_think
# 3      2   2750           2_vote_people_biden_trump
# 4      3    148            3_whale_kraken_boat_miss
# 5      4    133     4_comment_link_moderator_please
# 6      5     36             5_toshi_xcn_sokka_haiku
# 7      6     29         6_art_artist_painting_value
# 8      7     26  7_adoption_mass_mainstream_suuuure
# 9      8     26   8_quantum_computer_computing_hack
#
#                                       Representation  \
# 0  [coin, trump, crypto, people, go, get, make, l...
# 1  [trump, coin, buy, crypto, money, go, get, mak...
# 2  [go, bag, get, think, people, ha, like, know, ...
# 3  [vote, people, biden, trump, would, get, like,...
# 4  [whale, kraken, boat, miss, pole, touch, buy, ...
# 5  [comment, link, moderator, please, telegram, c...
# 6  [toshi, xcn, sokka, haiku, blast, good, divers...
# 7  [art, artist, painting, value, copyright, step...
# 8  [adoption, mass, mainstream, suuuure, permissi...
# 9  [quantum, computer, computing, hack, crypto, e...
#
#                                  Representative_Docs
# 0  [read early post read fool tell people go mort...
# 1  [meme market use anymore melania coin totally ...
# 2  [go say shit, people always think bag go pump ...
# 3  [people vote trump, ok I understand get third ...
# 4        [one kraken I buy, lol whale, kraken I get]
# 5  [greeting zealousidealcheck250 comment contain...
# 6  [$ 9 go move toshi, call toshi, toshi time bab...
# 7  [art steal, rich buy artist paint outright eve...
# 8  [bruh kill mass adoption, mass adoption finall...
# 9  [I see single quantum, quantum computer go cra...

# %%
trump_topic.to_csv("/content/drive/MyDrive/MasterThesis/trump_topic.csv", index=False)
