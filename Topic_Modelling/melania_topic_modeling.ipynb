# %% [markdown]
# # 1. Dataset Check

# %%
# Libraries
import pandas as pd
from google.colab import drive
import datetime

# %%
# Connect to Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# read dataset
data = pd.read_csv('/content/drive/MyDrive/MasterThesis/Reddit_Data/cleaned_melania.csv')
data.head()
# Out:
#             thread_title      thread_time_utc  thread_score  \
# 0  phantom solana wallet  2025-01-19 17:28:00             1
# 1  phantom solana wallet  2025-01-19 17:28:00             1
# 2  phantom solana wallet  2025-01-19 17:28:00             1
# 3  phantom solana wallet  2025-01-19 17:28:00             1
# 4  phantom solana wallet  2025-01-19 17:28:00             1
#
#       comment_time_utc  comment_score  \
# 0  2025-01-19 18:26:54              2
# 1  2025-01-21 00:26:06              1
# 2  2025-01-19 17:28:01              1
# 3  2025-01-20 18:52:10              2
# 4  2025-01-19 18:01:41              1
#
#                                         comment_text subreddit  \
# 0  your wallet address is public and everyone can...    solana
# 1                      yeah hide those you dont need    solana
# 2  warning 1 important read this post to keep you...    solana
# 3                        scam never touch an airdrop    solana
# 4  thank you any idea how my wallet recieved the ...    solana
#
#                                            full_text
# 0  phantom solana wallet your wallet address is p...
# 1  phantom solana wallet yeah hide those you dont...
# 2  phantom solana wallet warning 1 important read...
# 3  phantom solana wallet scam never touch an airdrop
# 4  phantom solana wallet thank you any idea how m...

# %%
data.shape
# Out:
# (16212, 8)

# %%
# Droping the data aqfter 28.02.2025 to align with the blockchain dat aanalysis
data['comment_time_utc'] = pd.to_datetime(data['comment_time_utc'])
cutoff = pd.to_datetime('2025-02-28')   # no utc=True
data.drop(data[data['comment_time_utc'] > cutoff].index, inplace=True)

# %%
data.shape
# Out:
# (15886, 8)

# %%
data.nunique()
# Out:
# thread_title          120
# thread_time_utc       121
# thread_score           65
# comment_time_utc    15308
# comment_score         292
# comment_text        14869
# subreddit              10
# full_text           15255
# dtype: int64

# %%
# dropping duplicates in order to avoid using bots comments or removed comments from analysis
duplicates = data[data.duplicated(subset='comment_text', keep=False)]
duplicates
# Out:
#                                             thread_title      thread_time_utc  \
# 2                                  phantom solana wallet  2025-01-19 17:28:00
# 7      ceo of bitcoin magazine says he appreciates $5...  2025-01-19 20:53:39
# 19     ceo of bitcoin magazine says he appreciates $5...  2025-01-19 20:53:39
# 24     ceo of bitcoin magazine says he appreciates $5...  2025-01-19 20:53:39
# 26     ceo of bitcoin magazine says he appreciates $5...  2025-01-19 20:53:39
# ...                                                  ...                  ...
# 15857                   just delist melania coin already  2025-02-26 17:56:40
# 15878  melania trump meme coin tanks in value just on...  2025-02-27 15:01:46
# 15905  melania trump meme coin tanks in value just on...  2025-02-27 15:01:46
# 15932  melania trump meme coin tanks in value just on...  2025-02-27 15:01:46
# 15950  melania trump meme coin tanks in value just on...  2025-02-27 15:01:46
#
#        thread_score    comment_time_utc  comment_score  \
# 2                 1 2025-01-19 17:28:01              1
# 7               428 2025-01-19 22:16:55             -9
# 19              428 2025-01-19 21:53:58              2
# 24              428 2025-01-19 21:25:32             -7
# 26              428 2025-01-19 22:22:12              1
# ...             ...                 ...            ...
# 15857           194 2025-02-26 19:03:11              1
# 15878           117 2025-02-27 15:36:03              1
# 15905           117 2025-02-27 18:40:35              1
# 15932           117 2025-02-27 16:20:52              1
# 15950           117 2025-02-27 16:36:34              1
#
#                                             comment_text       subreddit  \
# 2      warning 1 important read this post to keep you...          solana
# 7                                                   cope  CryptoCurrency
# 19                                                   NaN  CryptoCurrency
# 24                                                  cope  CryptoCurrency
# 26                                               exactly  CryptoCurrency
# ...                                                  ...             ...
# 15857                                            removed   CryptoMarkets
# 15878                                                NaN   CryptoMarkets
# 15905                                       you dont say   CryptoMarkets
# 15932                                            no shit   CryptoMarkets
# 15950                                           shocking   CryptoMarkets
#
#                                                full_text
# 2      phantom solana wallet warning 1 important read...
# 7      ceo of bitcoin magazine says he appreciates $5...
# 19     ceo of bitcoin magazine says he appreciates $5...
# 24     ceo of bitcoin magazine says he appreciates $5...
# 26     ceo of bitcoin magazine says he appreciates $5...
# ...                                                  ...
# 15857           just delist melania coin already removed
# 15878  melania trump meme coin tanks in value just on...
# 15905  melania trump meme coin tanks in value just on...
# 15932  melania trump meme coin tanks in value just on...
# 15950  melania trump meme coin tanks in value just on...
#
# [1189 rows x 8 columns]

# %%
data = data.drop_duplicates(subset='comment_text', keep='first')

# %%
data.shape
# Out:
# (14870, 8)

# %%
data = data[data["comment_text"].str.split().str.len() > 4]

# %%
data.shape
# Out:
# (12813, 8)

# %% [markdown]
# # 2. Topic Modelling

# %%
# !pip install bertopic[visualization] umap-learn hdbscan
# Out:
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.11/dist-packages (0.5.7)
# Requirement already satisfied: hdbscan in /usr/local/lib/python3.11/dist-packages (0.8.40)
# Requirement already satisfied: bertopic[visualization] in /usr/local/lib/python3.11/dist-packages (0.17.0)
# WARNING: bertopic 0.17.0 does not provide the extra 'visualization'
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from bertopic[visualization]) (2.0.2)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.11/dist-packages (from bertopic[visualization]) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.11/dist-packages (from bertopic[visualization]) (5.24.1)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.11/dist-packages (from bertopic[visualization]) (1.6.1)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from bertopic[visualization]) (3.4.1)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.11/dist-packages (from bertopic[visualization]) (4.67.1)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (1.15.2)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (0.5.13)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from hdbscan) (1.4.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic[visualization]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic[visualization]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic[visualization]) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=4.7.0->bertopic[visualization]) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=4.7.0->bertopic[visualization]) (24.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0->bertopic[visualization]) (3.6.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (4.51.3)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (2.6.0+cu124)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (0.30.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (11.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2025.3.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic[visualization]) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic[visualization]) (4.13.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic[visualization]) (1.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic[visualization]) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic[visualization]) (0.5.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2025.4.26)

# %%
# Import libraries
import pandas as pd
import umap
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer
from hdbscan import HDBSCAN
import nltk
import re
from nltk.corpus import stopwords
import spacy

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
nlp = spacy.load("en_core_web_sm")

# Text cleaning + lemmatization function
def clean_text(text):
    text = str(text).lower()
    text = re.sub(r"http\S+|www.\S+", "", text)
    text = re.sub(r"[^a-zA-Z0-9\s$]", "", text)
    text = re.sub(r"\s+", " ", text).strip()

    # Lemmatize and remove stopwords
    doc = nlp(text)
    words = [token.lemma_ for token in doc if token.lemma_ not in stop_words and not token.is_punct and not token.is_space]

    cleaned_text = " ".join(words)
    return cleaned_text
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Load cleaned dataset from previous part
df = data

# Cleaning using the prepared function
df["clean_comment_text"] = df["comment_text"].dropna().apply(clean_text)
texts = df["clean_comment_text"].dropna().tolist()

# HDBSCAN
hdbscan_model = HDBSCAN(
    min_cluster_size=20,
    min_samples=1,
    prediction_data=True
)

# UMAP model
umap_model = umap.UMAP(
    n_neighbors=10,
    n_components=5,
    min_dist=0.0,
    metric='cosine',
    random_state=42
)

# Embedding model
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

# Create BERTopic model
topic_model = BERTopic(
    hdbscan_model=hdbscan_model,
    umap_model=umap_model,
    embedding_model=embedding_model,
    calculate_probabilities=True,
    language="english",
    verbose=True
)

topics, probs = topic_model.fit_transform(texts)
# Out:
# 2025-05-06 21:56:34,478 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/401 [00:00<?, ?it/s]
# 2025-05-06 21:58:55,172 - BERTopic - Embedding - Completed ✓
# 2025-05-06 21:58:55,173 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-05-06 21:59:07,338 - BERTopic - Dimensionality - Completed ✓
# 2025-05-06 21:59:07,340 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-05-06 21:59:23,265 - BERTopic - Cluster - Completed ✓
# 2025-05-06 21:59:23,276 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-05-06 21:59:23,590 - BERTopic - Representation - Completed ✓

# %%
# After checking different options, we needed to reduce the number of topics. Based on the topic visualiations numer 8 seemed the most optimal
topic_model.reduce_topics(texts, nr_topics=9)
# Out:
# 2025-05-06 22:01:56,970 - BERTopic - Topic reduction - Reducing number of topics
# 2025-05-06 22:01:56,986 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-05-06 22:01:57,135 - BERTopic - Representation - Completed ✓
# 2025-05-06 22:01:57,139 - BERTopic - Topic reduction - Reduced number of topics from 10 to 9

# %% [markdown]
# # 3. Visualization and model evaluation

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="720e85e5-46d7-43f7-a149-613a3b8e26bb" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("720e85e5-46d7-43f7-a149-613a3b8e26bb")) {                    Plotly.newPlot(                        "720e85e5-46d7-43f7-a149-613a3b8e26bb",                        [{"customdata":[[0,"crypto | coin | trump | go | people",8056],[1,"rug | pull | rugpull | people | rugge",189],[2,"grift | grifter | family | grifte | keep",92],[3,"news | tweet | coffeezilla | twitter | video",70],[4,"clown | circus | crazy | insane | vote",64],[5,"burger | wendys | dump | doughnut | wake",44],[6,"thank | dm | appreciate | pls | please",35],[7,"smelania | damn | lol | sminem | smelanias",21]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[8056,189,92,70,64,44,35,21],"sizemode":"area","sizeref":5.035,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[8.111149,8.34582,10.14537,10.956751,12.066975,10.495676,8.646535,9.369173],"xaxis":"x","y":[3.32968,2.4031255,2.9628575,1.4100517,2.5363736,4.501125,3.237335,1.4700214],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666 ...

# %%
# Visualize hierarchy of topics
topic_model.visualize_hierarchy()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="62e08a8f-3a33-43d8-a87b-6d80ab79dd6a" class="plotly-graph-div" style="height:320px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("62e08a8f-3a33-43d8-a87b-6d80ab79dd6a")) {                    Plotly.newPlot(                        "62e08a8f-3a33-43d8-a87b-6d80ab79dd6a",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.9661222805976722,0.9661222805976722,0.0],"xaxis":"x","y":[-5.0,-5.0,-15.0,-15.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.6861798566077454,0.6861798566077454,0.0],"xaxis":"x","y":[-35.0,-35.0,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.8521004374878407,0.8521004374878407,0.6861798566077454],"xaxis":"x","y":[-25.0,-25.0,-40.0,-40.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.8521004374878407,0.9315668436950677,0.9315668436950677,0.0],"xaxis":"x","y":[-32.5,-32.5,-55.0,-55.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.943996406234572,0.943996406234572,0.0],"xaxis":"x","y":[-65.0,-65.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.9315668436950677,0.981463052621362,0.981463052621362,0.943996406234572],"xaxis":"x","y":[-43.75,-43.75,-70.0,-70.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9661222805976722,1.0084574931279404,1.0084574931279404,0.981463052621362],"xaxis":"x","y":[-10.0,-10.0,-56.875,-56.875],"yaxis":"y","type":"scatter"}],                        {"autosize":false,"height":320,"hovermode":"closest","showlegend":false,"width":1000,"xaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"ticks":"outside","type":"linear","zeroline":false},"yaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"tickmode":"array","ticks":"outside","ticktext":["6_thank_dm_appreciate","5_burger_wendys_dump","3_news_tweet_coffeezilla","0_crypto_coin_trump","1_rug_pull_rugpull","4_clown_circus_crazy","2_grift_grifter_family","7_smelania_damn_lol"],"tickvals":[-5.0,-15.0,-25.0,-35.0,-45.0,-55.0,-65.0,-75.0],"type":"linear","zeroline":false,"range":[-80.0,0.0]},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"], ...

# %%
# Visualize the top topics
topic_model.visualize_barchart(top_n_topics=10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9b910a48-289d-4cae-8063-be5a6691cfcd" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b910a48-289d-4cae-8063-be5a6691cfcd")) {                    Plotly.newPlot(                        "9b910a48-289d-4cae-8063-be5a6691cfcd",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.025939736655964097,0.026415921506342158,0.028377288809610483,0.028804576215029062,0.029980241147858522],"y":["people  ","go  ","trump  ","coin  ","crypto  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.04079535777597862,0.04285229713055945,0.07153805881249432,0.27917687481227266,0.3258133479551599],"y":["rugge  ","people  ","rugpull  ","pull  ","rug  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.053542392623111855,0.10981296899188976,0.11635039359811429,0.2853815971716667,0.5108487686943691],"y":["keep  ","grifte  ","family  ","grifter  ","grift  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.09247519213817715,0.10515746345406947,0.12549371438207527,0.13353832840673835,0.22719110470188303],"y":["video  ","twitter  ","coffeezilla  ","tweet  ","news  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.09426233959671361,0.09515775369915674,0.13320193415712467,0.25358142006559087,0.42688512334327844],"y":["vote  ","insane  ","crazy  ","circus  ","clown  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.0586801222172264,0.061343890901320086,0.13826462772391385,0.30541177970873934,0.604507792693584],"y":["wake  ","doughnut  ","dump  ","wendys  ","burger  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.11058200050957781,0.13846905564729242,0.30636619425627215,0.4167248642545985,0.6707126244072973],"y":["please  ","pls  ","appreciate  ","dm  ","thank  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.08779761868404394,0.08779761868404394,0.09892158033144569,0.10111379822481752,0.9158865455554386],"y":["smelanias  ","sminem  ","lol  ","damn  ","smelania  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555 ...

# %%
melania_topic = topic_model.get_topic_info()
melania_topic
# Out:
#    Topic  Count                              Name  \
# 0     -1   4242           -1_trump_coin_go_people
# 1      0   8056            0_crypto_coin_trump_go
# 2      1    189         1_rug_pull_rugpull_people
# 3      2     92     2_grift_grifter_family_grifte
# 4      3     70  3_news_tweet_coffeezilla_twitter
# 5      4     64       4_clown_circus_crazy_insane
# 6      5     44     5_burger_wendys_dump_doughnut
# 7      6     35         6_thank_dm_appreciate_pls
# 8      7     21        7_smelania_damn_lol_sminem
#
#                                       Representation  \
# 0  [trump, coin, go, people, buy, get, money, lik...
# 1  [crypto, coin, trump, go, people, get, like, b...
# 2  [rug, pull, rugpull, people, rugge, get, buy, ...
# 3  [grift, grifter, family, grifte, keep, griftin...
# 4  [news, tweet, coffeezilla, twitter, video, sel...
# 5  [clown, circus, crazy, insane, vote, elect, ye...
# 6  [burger, wendys, dump, doughnut, wake, sell, a...
# 7  [thank, dm, appreciate, pls, please, comment, ...
# 8  [smelania, damn, lol, sminem, smelanias, milia...
#
#                                  Representative_Docs
# 0  [I agree go rug pull need money also care imag...
# 1  [think crypto get elect I think lot people lik...
# 2  [go get rug pull, trump pull rug, rug pull trump]
# 3  [grift grift people eat, go grift end grift, g...
# 4  [people dump news mean, lately bad news dump n...
# 5  [market clown, every circus need clown, clown ...
# 6  [get buy next burger, always wendys burger kin...
# 7  [thank much I really appreciate, dm would grea...
# 8  [buy smelania really think, I want buy smelani...

# %%
melania_topic.to_csv("/content/drive/MyDrive/MasterThesis/melania_topic.csv", index=False)
